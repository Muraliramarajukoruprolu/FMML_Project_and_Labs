# %% [markdown]
# <a href="https://colab.research.google.com/github/Muraliramarajukoruprolu/FMML_Project_and_Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-19 01:35:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  63.7MB/s    in 1.1s
#
# 2024-04-19 01:36:00 (63.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14281  1605.07784v2  We consider the problem of Robust PCA in the f...    cs
# 40469   1111.0952v1  In the Nonnegative Matrix Factorization (NMF) ...    cs
# 9322   1505.04935v2  Continued reliance on human operators for mana...    cs
# 1793   1610.04658v2  We consider multi-class classification where t...  stat
# 4003    0806.1798v1  In image classification, merging the opinion o...    cs
# ...             ...                                                ...   ...
# 30771  1801.03145v2  Deep CNN-based object detection systems have a...    cs
# 24173  1612.09161v2  Real-world image recognition systems need to r...    cs
# 6923   1707.06487v2  In many problems of supervised tensor learning...  stat
# 11322  1509.05113v2  We consider the problem of learning the prefer...  stat
# 31670  cs/0211007v1  In biological data, it is often the case that ...    cs
#
#                                                    title  year  \
# 14281  Fast Algorithms for Robust PCA via Gradient De...  2016
# 40469  Computing a Nonnegative Matrix Factorization -...  2011
# 9322      Towards Data-Driven Autonomics in Data Centers  2015
# 1793   Simultaneous Learning of Trees and Representat...  2016
# 4003        Human expert fusion for image classification  2008
# ...                                                  ...   ...
# 30771  Visual and Semantic Knowledge Transfer for Lar...  2018
# 24173              Learning Visual N-Grams from Web Data  2016
# 6923   A Nonlinear Kernel Support Matrix Machine for ...  2017
# 11322  Revealed Preference at Scale: Learning Persona...  2015
# 31670  Approximating Incomplete Kernel Matrices by th...  2002
#
#                                                 keywords
# 14281  [partially, corruptions, completion, statistic...
# 40469  [nonnegative, factorization, nonnegative, nonn...
# 9322   [continued, operators, impediment, dimensions,...
# 1793   [classification, predictor, hierarchical, stru...
# 4003   [classification, important, different, evaluat...
# ...                                                  ...
# 30771  [detection, remarkable, detection, benchmarks,...
# 24173  [recognition, recognize, thousands, constitute...
# 6923   [supervised, naturally, represented, classifie...
# 11322  [preferences, heterogeneous, population, obser...
# 31670  [biological, available, unavailable, parametri...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14281    [partially, corruptions, completion, statistic...
# 40469    [nonnegative, factorization, nonnegative, nonn...
# 9322     [continued, operators, impediment, dimensions,...
# 1793     [classification, predictor, hierarchical, stru...
# 4003     [classification, important, different, evaluat...
#                                ...
# 17316    [proliferation, determining, interaction, proc...
# 22547    [investigate, regularization, convergence, con...
# 15647    [attentional, mechanism, effective, improving,...
# 31584    [automatic, viewfinder, immediately, interfere...
# 32638    [regression, technique, simultaneously, discov...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8811 words.
# Out of those 4571 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ad673a7d-a37c-4f40-9bea-59b2b16836c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad673a7d-a37c-4f40-9bea-59b2b16836c3")) {                    Plotly.newPlot(                        "ad673a7d-a37c-4f40-9bea-59b2b16836c3",                        [{"x":["corruptions","particular","partially","algorithm","standpoint","dimension","observations","computational","complexity","optimization","completion","exploited","algorithms","statistical","understood","observation","polynomial","available","conditions","applications","exponential","chemometrics","substantial","complement","polyhedral","knowledge","direction","frobenius","heuristics","improvements","separability","precisely","combinatorics","respectively","nonnegative","approximate","interesting","factorization","probability","identified","practical","communication","mechanics","computing","important","condition","intervention","executable","precision","including","collected","generated","continued","operations","ultimately","predictive","operating","autonomic","classification","characterizing","management","component","evaluation","dimensions","practicality","classifier","operators","performing","classifiers","evaluating","objective","representation","empirically","separable","optimizes","estimation","favorably","baselines","simultaneous","simultaneously","representations","hierarchical","structure","predictor","partitions","conditional","informations","considered","certainty","decisions","smarandache","different","information","graphical","artificial","importance","necessary","recognition","characteristics","intelligence","description","discarding","introduction","literature","implemented","generation","placement","installation","stability","technique","optimally","transmission","controller","performance","enhancing","evaluated","maximizes","computable","computability","solomonoff","induction","arithmetical","corresponding","reinforcement","hierarchy","incomputable","approximated","computation","concentrate","application","structured","prediction","efficiently","probabilistic","approximation","estimators","predictors","efficient","partition","assumption","addressing","mathematically","principles","challenges","designing","specified","perspective","requirements","achieving","considers","advantage","establishes","usefulness","possesses","simulated","interpretability","asymptotic","properties","theoretical","consistency","minimizing","normality","overcomes","determines","overfitting","discrimination","intercept","developed","hyperplane","imbalanced","expensive","calculating","procedure","unfortunately","computationally","belonging","approaches","contained","simplicity","solutions","population","positions","implementations","operation","potential","effectiveness","represents","consuming","continues","therefore","evaluates","candidate","measurement","developing","translation","exhaustive","determined","spectrograms","classifying","instrument"],"y":[1,289,54,779,2,65,69,273,225,299,29,25,603,155,25,53,63,300,125,480,48,1,39,11,2,362,59,3,52,102,5,25,3,73,11,106,78,32,175,48,138,65,9,130,370,47,13,5,72,264,69,171,5,61,9,58,22,1,480,23,44,98,246,39,8,146,45,76,96,47,170,355,63,20,10,216,14,59,32,113,228,100,348,15,13,89,2,113,5,65,5,725,687,61,135,84,72,378,83,103,75,4,32,131,99,150,12,2,39,237,15,11,16,878,27,155,15,6,2,2,19,2,121,106,33,2,25,144,5,225,96,235,158,166,125,11,11,388,29,71,20,13,42,129,45,34,65,52,77,27,83,9,21,4,61,21,24,215,158,62,45,2,10,14,22,18,0,220,3,12,61,12,115,38,98,15,454,20,19,158,55,19,36,37,167,230,48,24,10,146,14,51,34,72,128,22,28,6,27,6],"type":"bar"},{"x":["corruptions","particular","partially","algorithm","standpoint","dimension","observation ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4571,), (4571, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.79

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Autodetection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>of</span> <span style=''>Hidden</span> <span style=''>Cultural</span> <span style=''>City</span> <span style=''>Districts</span> <span style=''>from</span> <span style=''>Yelp</span> <span style=''>Reviews</span> <br/><br/><span style=''>Topic</span> <span style=''>models</span> <span style=''>are</span> <span style=''>a</span> <span style=''>way</span> <span style=''>to</span> <span style=''>discover</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>themes</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>otherwise</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>unstructured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5238095238095238);'>documents</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style=''>used</span> <span style=''>the</span> <span style=''>Latent</span> <span style='background-color:rgba(255, 0, 0, 0.5072463768115942);'>Dirichlet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Allocation</span> <span style=''>(LDA)</span> <span style=''>topic</span> <span style=''>model</span> <span style=''>on</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>Yelp</span> <span style=''>reviews</span> <span style=''>to</span> <span style=''>classify</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>restaurants</span> <span style=''>based</span> <span style=''>off</span> <span style=''>of</span> <span style=''>their</span> <span style=''>reviews</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>hypothesize</span> <span style=''>that</span> <span style=''>within</span> <span style=''>a</span> <span style=''>city</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>restaurants</span> <span style=''>can</span> <span style=''>be</span> <span style=''>grouped</span> <span style=''>into</span> <span style=''>similar</span> <span style=''>clusters</span> <span style=''>based</span> <span style=''>on</span> <span style=''>both</span> <span style=''>location</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>similarity</span> <span style=''>We</span> <span style=''>used</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3205828779599271);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>K</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style=''>Mixture</span> <span style=''>Model</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>uncover</span> <span style=''>and</span> <span style=''>classify</span> <span style=''>districts</span> <span style=''>both</span> <span style=''>well</span> <span style=''>known</span> <span style=''>and</span> <span style=''>hidden</span> <span style=''>(ie</span> <span style=''>cultural</span> <span style=''>areas</span> <span style=''>like</span> <span style=''>Chinatown</span> <span style=''>or</span> <span style=''>hearsay</span> <span style=''>like</span> <span style=''>the</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>averaging</span> <span style=''>with</span> <span style=''>particle</span> <span style=''>Gibbs</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>into</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style=''>For</span> <span style=''>each</span> <span style=''>class</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>features</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>by</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposable</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>Emphasis</span> <span style=''>is</span> <span style=''>then</span> <span style=''>placed</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>averaging</span> <span style=''>which</span> <span style=''>takes</span> <span style=''>full</span> <span style=''>account</span> <span style=''>of</span> <span style=''>the</span> <span style=''>class</span> <span style=''>specific</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>averaging</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>graph</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>Even</span> <span style=''>though</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>severely</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>model</span> <span style=''>space</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposable</span> <span style=''>models</span> <span style=''>is</span> <span style=''>still</span> <span style=''>immense</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>Extended</span> <span style=''>Cencov</span> <span style=''>Campbell</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Characterization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3023696682464454);'>Information</span> <span style=''>Geometry</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>axiomatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3023696682464454);'>information</span> <span style=''>geometry</span> <span style=''>for</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style=''>and</span> <span style=''>the</span> <span style=''>nonnormalized</span> <span style=''>cases</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterization</span> <span style=''>extends</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>axiomatic</span> <span style='background-color:rgba(255, 0, 0, 0.3103448275862069);'>derivation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Fisher</span> <span style=''>geometry</span> <span style=''>by</span> <span style=''>Cencov</span> <span style=''>and</span> <span style=''>Campbell</span> <span style=''>to</span> <span style=''>the</span> <span style=''>cone</span> <span style=''>of</span> <span style=''>positive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>models</span> <span style=''>and</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>to</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3295774647887324);'>distributions</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>close</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>I</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>divergence</span> <span style=''>and</span> <span style=''>the</span> <span style=''>product</span> <span style=''>Fisher</span> <span style='background-color:rgba(0, 255, 0, 0.3023696682464454);'>information</span> <span style=''>metric</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterization</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>axiomatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>primal</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.5371549893842889);'>regression</span> <span style=''>and</span> <span style=''>AdaBoost</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>End</span> <span style=''>to</span> <span style=''>End</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Polyphonic</span> <span style=''>Piano</span> <span style=''>Music</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transcription</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polyphonic</span> <span style=''>piano</span> <span style=''>music</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transcription</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analogous</span> <span style=''>to</span> <span style=''>speech</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>systems</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprises</span> <span style=''>an</span> <span style=''>acoustic</span> <span style=''>model</span> <span style=''>and</span> <span style=''>a</span> <span style=''>music</span> <span style=''>language</span> <span style=''>model</span> <span style=''>The</span> <span style=''>acoustic</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>pitches</span> <span style=''>in</span> <span style=''>a</span> <span style=''>frame</span> <span style=''>of</span> <span style=''>audio</span> <span style=''>The</span> <span style=''>language</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>that</span> <span style=''>models</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>pitch</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>over</span> <span style=''>time</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>is</span> <span style=''>general</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>transcribe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polyphonic</span> <span style=''>music</span> <span style=''>without</span> <span style=''>imposing</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>on</span> <span style=''>the</span> <span style=''>polyphony</span> <span style=''>The</span> <span style=''>acoustic</span> <span style=''>and</span> <span style=''>language</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>are</span> <span style=''>combined</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style='backg ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12642450142450143)
# 	processing (0.10576923076923077)
# 	knowledge (0.12891737891737892)
# 	experimental (0.13782051282051283)
# 	information (0.24465811965811965)
# 	segmentation (0.07443019943019943)
# 	detection (0.11716524216524217)
# 	different (0.2581908831908832)
# 	convolutional (0.13924501424501423)
# 	recognition (0.1346153846153846)
#
# Some Statistics words are:
# 	stochastic (0.13654618473895583)
# 	theoretical (0.14708835341365462)
# 	estimation (0.17520080321285142)
# 	variables (0.1495983935742972)
# 	statistical (0.16265060240963855)
# 	algorithm (0.39156626506024095)
# 	distribution (0.18674698795180722)
# 	dimensional (0.19076305220883535)
# 	inference (0.20933734939759036)
# 	regression (0.1817269076305221)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="839fd3b3-0d94-4ee8-8c81-f03cf51f0243" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("839fd3b3-0d94-4ee8-8c81-f03cf51f0243")) {                    Plotly.newPlot(                        "839fd3b3-0d94-4ee8-8c81-f03cf51f0243",                        [{"x":["corruptions","particular","partially","algorithm","standpoint","dimension","observations","computational","complexity","optimization","completion","exploited","algorithms","statistical","understood","observation","polynomial","available","conditions","applications","exponential","chemometrics","substantial","complement","polyhedral","knowledge","direction","frobenius","heuristics","improvements","separability","precisely","combinatorics","respectively","nonnegative","approximate","interesting","factorization","probability","identified","practical","communication","mechanics","computing","important","condition","intervention","executable","precision","including","collected","generated","continued","operations","ultimately","predictive","operating","autonomic","classification","characterizing","management","component","evaluation","dimensions","practicality","classifier","operators","performing","classifiers","evaluating","objective","representation","empirically","separable","optimizes","estimation","favorably","baselines","simultaneous","simultaneously","representations","hierarchical","structure","predictor","partitions","conditional","informations","considered","certainty","decisions","smarandache","different","information","graphical","artificial","importance","necessary","recognition","characteristics","intelligence","description","discarding","introduction","literature","implemented","generation","placement","installation","stability","technique","optimally","transmission","controller","performance","enhancing","evaluated","maximizes","computable","computability","solomonoff","induction","arithmetical","corresponding","reinforcement","hierarchy","incomputable","approximated","computation","concentrate","application","structured","prediction","efficiently","probabilistic","approximation","estimators","predictors","efficient","partition","assumption","addressing","mathematically","principles","challenges","designing","specified","perspective","requirements","achieving","considers","advantage","establishes","usefulness","possesses","simulated","interpretability","asymptotic","properties","theoretical","consistency","minimizing","normality","overcomes","determines","overfitting","discrimination","intercept","developed","hyperplane","imbalanced","expensive","calculating","procedure","unfortunately","computationally","belonging","approaches","contained","simplicity","solutions","population","positions","implementations","operation","potential","effectiveness","represents","consuming","continues","therefore","evaluates","candidate","measurement","developing","translation","exhaustive","determined","spectrograms","classifying","instrument","surprisingly","frequency","particularly","experiments","dependencies","quadratically","exchangeable","primitive","simulators","proposals","programming","likelihood","compositional","histories","existential","represent","modifying","execution","encapsulates","variables","procedures","programmable","extensible","metropolis","sequences","implementation","interactive","expressive","fragments","strategies","sufficiently","stochastic","inference","variational","implement","specifies","interface","techniques","evidences","functions","utilization","intelligently","invention","empirical","heuristic","correlation","demonstrate","improvement","outperforms","synthesis","automatic","distributions","evaluations","regression","iterative","instances ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	intercept
# 	postulated
# 	factorize
# 	robustification
# 	distributionally
# 	nonadaptive
# 	cooccurence
# 	discriminants
# 	sparsistency
# 	minimally
# 	refitting
# 	ellipsoidal
# 	electroencephalography
# 	safeguard
# 	propensity
# 	prohibits
# 	compressibility
# 	emphmulti
# 	changepoints
# 	elections
# Some words which never appear in Statistics papers:
# 	standpoint
# 	continued
# 	informations
# 	certainty
# 	smarandache
# 	installation
# 	computability
# 	solomonoff
# 	arithmetical
# 	incomputable
# 	existential
# 	programmable
# 	evidences
# 	intelligently
# 	normalize
# 	reconfigurable
# 	compilation
# 	reimplement
# 	dialogues
# 	initiative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.062693332516616e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
